# %%
import pandas as pd
import numpy as np

df = pd.read_csv("customer.csv")
df.head()
# Out:
#    Age  AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# 0   37   57722.57241                 19            5.908826
# 1   63   21328.92588                 10            6.970749
# 2   60  150537.74250                 19           35.004954
# 3   19   63508.76255                 10           14.818000
# 4   54  100399.55840                 19           55.925462
#
#    CustomerTenureYears  LastPurchaseDaysAgo  Gender ProductCategory  \
# 0             1.093430                   11    Male       Furniture
# 1             0.649246                   20  Female       Furniture
# 2             3.858211                   25    Male     Electronics
# 3             7.554374                   20    Male       Furniture
# 4             0.197411                   92    Male     Electronics
#
#   PreferredDevice Region ReferralSource CustomerSegment  LoyaltyProgram  \
# 0         Desktop  South       Paid Ads         Regular               1
# ...

# %%
df.isnull().sum()
# Out:
# Age                       0
# AnnualIncome              0
# NumberOfPurchases         0
# TimeSpentOnWebsite        0
# CustomerTenureYears       0
# LastPurchaseDaysAgo       0
# Gender                    0
# ProductCategory           0
# PreferredDevice           0
# Region                    0
# ReferralSource            0
# CustomerSegment           0
# LoyaltyProgram            0
# DiscountsAvailed          0
# SessionCount              0
# CustomerSatisfaction      0
# PurchaseStatus            0
# SpendingScore           540
# dtype: int64

# %%
import math
median_SpendingScore = math.floor(df.SpendingScore.median())
median_SpendingScore
# Out:
# 47

# %%
df.SpendingScore = df.SpendingScore.fillna(median_SpendingScore)
df
# Out:
#         Age  AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# 0        37   57722.57241                 19            5.908826
# 1        63   21328.92588                 10            6.970749
# 2        60  150537.74250                 19           35.004954
# 3        19   63508.76255                 10           14.818000
# 4        54  100399.55840                 19           55.925462
# ...     ...           ...                ...                 ...
# 499995   56  113252.44120                 16           26.327274
# 499996   40   59758.01615                 13            7.124139
# 499997   50   64968.69666                 10           28.440505
# 499998   38  150832.32070                  8           50.161579
# 499999   75  103195.11530                  4           23.528559
#
#         CustomerTenureYears  LastPurchaseDaysAgo  Gender ProductCategory  \
# 0                  1.093430                   11    Male       Furniture
# ...

# %%
dummies = pd.get_dummies(df['Gender'], dtype=int)
dummies
# Out:
#         Female  Male
# 0            0     1
# 1            1     0
# 2            0     1
# 3            0     1
# 4            0     1
# ...        ...   ...
# 499995       0     1
# 499996       0     1
# 499997       0     1
# 499998       1     0
# 499999       0     1
#
# [500000 rows x 2 columns]

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#         Age  AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# 0        37   57722.57241                 19            5.908826
# 1        63   21328.92588                 10            6.970749
# 2        60  150537.74250                 19           35.004954
# 3        19   63508.76255                 10           14.818000
# 4        54  100399.55840                 19           55.925462
# ...     ...           ...                ...                 ...
# 499995   56  113252.44120                 16           26.327274
# 499996   40   59758.01615                 13            7.124139
# 499997   50   64968.69666                 10           28.440505
# 499998   38  150832.32070                  8           50.161579
# 499999   75  103195.11530                  4           23.528559
#
#         CustomerTenureYears  LastPurchaseDaysAgo  Gender ProductCategory  \
# 0                  1.093430                   11    Male       Furniture
# ...

# %%
df = merged.drop(['Gender','Female'],axis='columns')
df
# Out:
#         Age  AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# 0        37   57722.57241                 19            5.908826
# 1        63   21328.92588                 10            6.970749
# 2        60  150537.74250                 19           35.004954
# 3        19   63508.76255                 10           14.818000
# 4        54  100399.55840                 19           55.925462
# ...     ...           ...                ...                 ...
# 499995   56  113252.44120                 16           26.327274
# 499996   40   59758.01615                 13            7.124139
# 499997   50   64968.69666                 10           28.440505
# 499998   38  150832.32070                  8           50.161579
# 499999   75  103195.11530                  4           23.528559
#
#         CustomerTenureYears  LastPurchaseDaysAgo ProductCategory  \
# 0                  1.093430                   11       Furniture
# ...

# %%
df.isnull().sum()
# Out:
# Age                     0
# AnnualIncome            0
# NumberOfPurchases       0
# TimeSpentOnWebsite      0
# CustomerTenureYears     0
# LastPurchaseDaysAgo     0
# ProductCategory         0
# PreferredDevice         0
# Region                  0
# ReferralSource          0
# CustomerSegment         0
# LoyaltyProgram          0
# DiscountsAvailed        0
# SessionCount            0
# CustomerSatisfaction    0
# PurchaseStatus          0
# SpendingScore           0
# Male                    0
# dtype: int64

# %%
features = [
    'Age',
    'AnnualIncome',
    'NumberOfPurchases',
    'TimeSpentOnWebsite',
    'LastPurchaseDaysAgo',
    'Male',
    'SpendingScore'
]

X = df[features]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# D:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# D:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...

# %%
plt.plot(range(1, 11), wcss)
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)

clusters = kmeans.fit_predict(X_scaled)

df['Cluster'] = clusters
# Out:
# D:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# D:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...

# %% [markdown]
# The elbow curve shows a sharp reduction in WCSS until K = 5 and only marginal improvements afterward, indicating that 5 clusters optimally balance cluster compactness and model simplicity for customer segmentation.

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X_scaled, clusters, sample_size=10000, random_state=42)
print("Silhouette Score:", score)
# Out:
# D:\anaconda\lib\site-packages\sklearn\metrics\pairwise.py:53: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# Silhouette Score: 0.15706315035714974

# %%
plt.scatter(df['AnnualIncome'], df['SpendingScore'], c=clusters)
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.title("Customer Clusters")
plt.show()

# %%
df.groupby('Cluster').mean()
# Out:
#                Age  AnnualIncome  NumberOfPurchases  TimeSpentOnWebsite  \
# Cluster
# 0        43.947683  84957.464609          16.254307           30.551368
# 1        43.930359  85034.489468           5.908686           30.624958
# 2        43.848800  85229.184710           5.725147           30.634686
# 3        44.063015  84942.223834          15.144309           30.553476
# 4        43.951734  85159.703489          16.485008           30.588642
#
#          CustomerTenureYears  LastPurchaseDaysAgo  LoyaltyProgram  \
# Cluster
# 0                   2.173028            30.685934        0.560098
# 1                   2.157839            54.568490        0.435179
# 2                   2.165105            56.417448        0.432258
# 3                   2.166864           143.717833        0.549168
# 4                   2.155990            31.637623        0.560467
#
#          DiscountsAvailed  SessionCount  CustomerSatisfaction  PurchaseStatus  \
# Cluster
# ...

# %% [markdown]
# KMeans clustering divided customers into five segments based on their purchase frequency and recency, identifying loyal high spenders, low-engagement users, inactive customers, churn-risk customers, and premium top performers.
